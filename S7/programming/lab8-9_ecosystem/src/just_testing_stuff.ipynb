# %%
import pandas as pd
from utils import check_hexacolor, hexacolor_to_int
from monkey_model import Monkey
from monkey_classif import read_monkeys_from_csv

# %%
read_monkeys_from_csv("../data/monkeys.csv")
# Out:
#         species   size   weight    color  \
# 1        bonobo  0.713   47.139  #2e1628
# 3        bonobo  0.770   45.065  #12211a
# 5        bonobo  0.705   31.771  #1c1729
# 10      gorilla  1.542  213.395  #1d1b1e
# 11       bonobo  0.714   53.511  #14222d
# ...         ...    ...      ...      ...
# 2983     bonobo  0.759   39.023  #171018
# 2989  orangutan  1.000   38.338  #ce5811
# 2990     bonobo  0.714   39.007  #30212c
# 2993     bonobo  0.703   44.935  #13122f
# 2995     bonobo  0.709   32.094  #1f1c12
#
#                                                  monkey  color_int         bmi
# 1      Monkey (bonobo), 47.139kg, 0.713cm, fur: #2e1628    3020328   92.725953
# 3       Monkey (bonobo), 45.065kg, 0.77cm, fur: #12211a    1188122   76.007758
# 5      Monkey (bonobo), 31.771kg, 0.705cm, fur: #1c1729    1840937   63.922338
# 10    Monkey (gorilla), 213.395kg, 1.542cm, fur: #1d...    1907486   89.746081
# ...
